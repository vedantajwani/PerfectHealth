# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/miniconda3/envs/perfectHealth/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in /opt/miniconda3/envs/perfectHealth/lib/python3.10/site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/perfectHealth/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/perfectHealth/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/perfectHealth/lib/python3.10/site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/perfectHealth/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
import csv
import json
import numpy as np
import pandas as pd

INPUT_CSV = Path("../data/oura_synthetic_dataset.csv")

OUT_DIR = Path("../data")
OUT_JSON = OUT_DIR / "oura_synthetic_dataset.json"
OUT_JSONL = OUT_DIR / "oura_synthetic_dataset.jsonl"

OUT_DIR.mkdir(parents=True, exist_ok=True)

print("Input:", INPUT_CSV)
# Out:
# Input: ../data/oura_synthetic_dataset.csv

# %%
rows = []

with INPUT_CSV.open(newline="") as f:
    reader = csv.reader(f)
    header = next(reader)

    for r in reader:
        # Remove trailing empty column if present
        if len(r) == len(header) + 1 and r[-1] == "":
            r = r[:-1]

        # Normalize length
        if len(r) < len(header):
            r += [""] * (len(header) - len(r))
        elif len(r) > len(header):
            r = r[:len(header)]

        rows.append(r)

raw_df = pd.DataFrame(rows, columns=header)

print("Raw shape:", raw_df.shape)
raw_df.head()
# Out:
# Raw shape: (105, 29)
#     user_id        date     data_type sleep_score sleep_total_duration_sec  \
# 0  user_001  2024-01-15         sleep          85                    28800
# 1  user_001  2024-01-15     readiness
# 2  user_001  2024-01-15      activity
# 3  user_001  2024-01-15  daily_stress
# 4  user_001  2024-01-15          spo2
#
#   sleep_deep_duration_sec sleep_rem_duration_sec sleep_light_duration_sec  \
# 0                    7200                   6480                    14400
# 1
# 2
# 3
# 4
#
#   sleep_awake_time_sec sleep_efficiency  ... activity_active_calories  \
# 0                  720               94  ...
# 1                                        ...
# 2                                        ...                     2456
# 3                                        ...
# 4                                        ...
#
#   activity_high_activity_time_sec activity_medium_activity_time_sec  \
# 0
# 1
# 2                             892                              3240
# 3
# 4
#
#   activity_low_activity_time_sec body_temperature_deviation  \
# 0
# 1                                                       0.2
# 2                           5820                       7680
# 3
# 4
#
#   stress_high_time_sec recovery_high_time_sec spo2_average vo2_max  \
# 0
# 1
# 2
# 3                                        2340        12600
# 4                                                             96.8
#
#   cardiovascular_age
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 29 columns]

# %%
df = raw_df.copy()

# Empty strings → NaN
df = df.replace({"": np.nan})

# Parse date
df["date"] = pd.to_datetime(df["date"], errors="coerce").dt.date

# Convert numeric columns
key_cols = {"user_id", "date", "data_type"}

for col in df.columns:
    if col not in key_cols:
        df[col] = pd.to_numeric(df[col], errors="coerce")

df.head()
# Out:
# /var/folders/47/95hnkgmn6wd0lwmkxyqfvjr40000gn/T/ipykernel_50532/2377260554.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace({"": np.nan})
#     user_id        date     data_type  sleep_score  sleep_total_duration_sec  \
# 0  user_001  2024-01-15         sleep         85.0                   28800.0
# 1  user_001  2024-01-15     readiness          NaN                       NaN
# 2  user_001  2024-01-15      activity          NaN                       NaN
# 3  user_001  2024-01-15  daily_stress          NaN                       NaN
# 4  user_001  2024-01-15          spo2          NaN                       NaN
#
#    sleep_deep_duration_sec  sleep_rem_duration_sec  sleep_light_duration_sec  \
# 0                   7200.0                  6480.0                   14400.0
# 1                      NaN                     NaN                       NaN
# 2                      NaN                     NaN                       NaN
# 3                      NaN                     NaN                       NaN
# 4                      NaN                     NaN                       NaN
#
#    sleep_awake_time_sec  sleep_efficiency  ...  activity_active_calories  \
# 0                 720.0              94.0  ...                       NaN
# 1                   NaN               NaN  ...                       NaN
# 2                   NaN               NaN  ...                    2456.0
# 3                   NaN               NaN  ...                       NaN
# 4                   NaN               NaN  ...                       NaN
#
#    activity_high_activity_time_sec  activity_medium_activity_time_sec  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                            892.0                             3240.0
# 3                              NaN                                NaN
# 4                              NaN                                NaN
#
#    activity_low_activity_time_sec  body_temperature_deviation  \
# 0                             NaN                         NaN
# 1                             NaN                         0.2
# 2                          5820.0                      7680.0
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#    stress_high_time_sec  recovery_high_time_sec  spo2_average  vo2_max  \
# 0                   NaN                     NaN           NaN      NaN
# 1                   NaN                     NaN           NaN      NaN
# 2                   NaN                     NaN           NaN      NaN
# 3                   NaN                  2340.0       12600.0      NaN
# 4                   NaN                     NaN           NaN     96.8
#
#    cardiovascular_age
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 29 columns]

# %%
def first_non_null(series):
    s = series.dropna()
    return s.iloc[0] if len(s) else np.nan

merged = (
    df.groupby(["user_id", "date"], as_index=False)
      .agg({col: first_non_null for col in df.columns if col != "data_type"})
)

print("Merged shape:", merged.shape)
merged.head()
# Out:
# Merged shape: (26, 28)
#     user_id        date  sleep_score  sleep_total_duration_sec  \
# 0  user_001  2024-01-15         85.0                   28800.0
# 1  user_001  2024-01-16         79.0                   27000.0
# 2  user_001  2024-01-17         88.0                   29700.0
# 3  user_001  2024-01-18         86.0                   29100.0
# 4  user_002  2024-01-15         72.0                   25200.0
#
#    sleep_deep_duration_sec  sleep_rem_duration_sec  sleep_light_duration_sec  \
# 0                   7200.0                  6480.0                   14400.0
# 1                   6300.0                  5940.0                   13860.0
# 2                   7740.0                  6840.0                   14520.0
# 3                   7380.0                  6660.0                   14460.0
# 4                   5400.0                  5040.0                   13680.0
#
#    sleep_awake_time_sec  sleep_efficiency  sleep_latency_sec  ...  \
# 0                 720.0              94.0              480.0  ...
# 1                 900.0              91.0              600.0  ...
# 2                 600.0              95.0              390.0  ...
# 3                 600.0              94.0              420.0  ...
# 4                1080.0              88.0              720.0  ...
#
#    activity_active_calories  activity_high_activity_time_sec  \
# 0                    2456.0                            892.0
# 1                    2234.0                            745.0
# 2                    2765.0                           1045.0
# 3                    2689.0                            989.0
# 4                    2145.0                            654.0
#
#    activity_medium_activity_time_sec  activity_low_activity_time_sec  \
# 0                             3240.0                          5820.0
# 1                             2880.0                          5040.0
# 2                             4320.0                          7560.0
# 3                             3960.0                          7020.0
# 4                             2160.0                          4320.0
#
#    body_temperature_deviation  stress_high_time_sec  recovery_high_time_sec  \
# 0                         0.2                   NaN                  2340.0
# 1                         0.3                   NaN                     NaN
# 2                      8640.0                  -0.1                     NaN
# 3                         0.0                   NaN                  2040.0
# 4                         0.5                   NaN                     NaN
#
#    spo2_average  vo2_max  cardiovascular_age
# 0       12600.0     96.8                 NaN
# 1           NaN     97.1                 NaN
# 2           NaN      NaN                 NaN
# 3       13680.0      NaN                 NaN
# 4           NaN      NaN                45.2
#
# [5 rows x 28 columns]

# %%
def to_record(row):
    def g(key, default=None):
        val = row.get(key)
        if pd.isna(val):
            return default
        if isinstance(val, (np.integer, np.floating)):
            return val.item()
        return val

    return {
        "user_id": g("user_id"),
        "date": str(g("date")),

        "sleep": {
            "score": g("sleep_score"),
            "total_duration_sec": g("sleep_total_duration_sec"),
            "deep_duration_sec": g("sleep_deep_duration_sec"),
            "rem_duration_sec": g("sleep_rem_duration_sec"),
            "light_duration_sec": g("sleep_light_duration_sec"),
            "avg_hrv": g("average_hrv"),
            "avg_heart_rate": g("average_heart_rate"),
        },

        "readiness": {
            "score": g("readiness_score"),
            "temperature_deviation": g("body_temperature_deviation"),
        },

        "activity": {
            "score": g("activity_score"),
            "steps": g("activity_steps"),
            "total_calories": g("activity_total_calories"),
            "active_calories": g("activity_active_calories"),
        }
    }

records = [to_record(r) for _, r in merged.iterrows()]

records[0]
# Out:
# {'user_id': 'user_001',
#  'date': '2024-01-15',
#  'sleep': {'score': 85.0,
#   'total_duration_sec': 28800.0,
#   'deep_duration_sec': 7200.0,
#   'rem_duration_sec': 6480.0,
#   'light_duration_sec': 14400.0,
#   'avg_hrv': 65.0,
#   'avg_heart_rate': 58.0},
#  'readiness': {'score': 82.0, 'temperature_deviation': 0.2},
#  'activity': {'score': None,
#   'steps': 78.0,
#   'total_calories': 8542.0,
#   'active_calories': 2456.0}}

# %%
bad = []

for i, r in enumerate(records):
    if not r["date"]:
        bad.append((i, "missing date"))
    if not any([
        r["sleep"]["score"],
        r["readiness"]["score"],
        r["activity"]["score"],
    ]):
        bad.append((i, "no scores"))

if bad:
    print("⚠️ Issues:", bad[:5])
else:
    print("✅ Dataset looks good")
# Out:
# ✅ Dataset looks good

# %%
# JSON array
with OUT_JSON.open("w") as f:
    json.dump(records, f, indent=2)

# JSONL (one record per line)
with OUT_JSONL.open("w") as f:
    for r in records:
        f.write(json.dumps(r) + "\n")

print("Saved:")
print(" -", OUT_JSON)
print(" -", OUT_JSONL)
# Out:
# Saved:
#  - ../data/oura_synthetic_dataset.json
#  - ../data/oura_synthetic_dataset.jsonl
